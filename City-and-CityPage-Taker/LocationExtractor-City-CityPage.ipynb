# %%
import pandas as pd

# %%
df = pd.read_json('cleanedLocationV2.json')

# %%
df
# Out:
#                                                          0    \
# city                                     Tangerang Kabupaten
# state
# city_page  {'display_name': 'Binong, Indonesia', 'id': '1...
#
#                                                          1    \
# city                                           Jakarta Pusat
# state
# city_page  {'display_name': 'Jakarta, Indonesia', 'id': '...
#
#                                                          2    \
# city                                         Jakarta Selatan
# state
# city_page  {'display_name': 'Jakarta, Indonesia', 'id': '...
#
#                                                          3    \
# city                                           Sukabumi Kota
# state
# city_page  {'display_name': 'Sukabumi', 'id': '1129790253...
#
#                                                          4    \
# city                                             Bekasi Kota
# state
# ...

# %%
city = df.iloc[0]

# %%
city
# Out:
# 0      Tangerang Kabupaten
# 1            Jakarta Pusat
# 2          Jakarta Selatan
# 3            Sukabumi Kota
# 4              Bekasi Kota
#               ...
# 711          Jakarta Timur
# 712         Tangerang Kota
# 713            Bekasi Kota
# 714         Tangerang Kota
# 715          Jakarta Pusat
# Name: city, Length: 716, dtype: object

# %%
city.to_json('city.json')

# %%
citypage = df.iloc[2]

# %%
citypage
# Out:
# 0      {'display_name': 'Binong, Indonesia', 'id': '1...
# 1      {'display_name': 'Jakarta, Indonesia', 'id': '...
# 2      {'display_name': 'Jakarta, Indonesia', 'id': '...
# 3      {'display_name': 'Sukabumi', 'id': '1129790253...
# 4      {'display_name': 'Bekasi', 'id': '112413425436...
#                              ...
# 711    {'display_name': 'Jakarta, Indonesia', 'id': '...
# 712    {'display_name': 'Tangerang', 'id': '107978652...
# 713    {'display_name': 'Bekasi', 'id': '112413425436...
# 714    {'display_name': 'Tangerang', 'id': '107978652...
# 715    {'display_name': 'Jakarta, Indonesia', 'id': '...
# Name: city_page, Length: 716, dtype: object

# %%
citypage.to_json('citypage.json')
